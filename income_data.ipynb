# %%
import pandas as pd

# %%
df=pd.read_csv("/content/income_data.csv")

# %%
df
# Out:
#      Unnamed: 0    income  happiness
# 0             1  3.862647   2.314489
# 1             2  4.979381   3.433490
# 2             3  4.923957   4.599373
# 3             4  3.214372   2.791114
# 4             5  7.196409   5.596398
# ..          ...       ...        ...
# 493         494  5.249209   4.568705
# 494         495  3.471799   2.535002
# 495         496  6.087610   4.397451
# 496         497  3.440847   2.070664
# 497         498  4.530545   3.710193
#
# [498 rows x 3 columns]

# %%
df.head()
# Out:
#    Unnamed: 0    income  happiness
# 0           1  3.862647   2.314489
# 1           2  4.979381   3.433490
# 2           3  4.923957   4.599373
# 3           4  3.214372   2.791114
# 4           5  7.196409   5.596398

# %%
df.size
# Out:
# 1494

# %%
df.shape
# Out:
# (498, 3)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'income', 'happiness'], dtype='object')

# %%
X=df[["income"]]
y=df["happiness"]

# %%
X
# Out:
#        income
# 0    3.862647
# 1    4.979381
# 2    4.923957
# 3    3.214372
# 4    7.196409
# ..        ...
# 493  5.249209
# 494  3.471799
# 495  6.087610
# 496  3.440847
# 497  4.530545
#
# [498 rows x 1 columns]

# %%
y
# Out:
# 0      2.314489
# 1      3.433490
# 2      4.599373
# 3      2.791114
# 4      5.596398
#          ...
# 493    4.568705
# 494    2.535002
# 495    4.397451
# 496    2.070664
# 497    3.710193
# Name: happiness, Length: 498, dtype: float64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# income        0
# happiness     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train
# Out:
#        income
# 46   5.196120
# 31   1.855645
# 113  5.361503
# 334  2.381385
# 274  4.990549
# ..        ...
# 106  7.176400
# 270  3.859892
# 348  5.693725
# 435  5.754941
# 102  2.286495
#
# [373 rows x 1 columns]

# %%
y_train
# Out:
# 46     4.087631
# 31     1.590356
# 113    5.231863
# 334    2.176322
# 274    3.451773
#          ...
# 106    5.029952
# 270    2.719432
# 348    3.999703
# 435    3.980195
# 102    1.893557
# Name: happiness, Length: 373, dtype: float64

# %%
X_test
# Out:
#        income
# 487  4.243873
# 73   2.864664
# 231  4.223554
# 175  2.274523
# 237  2.210696
# ..        ...
# 415  4.924950
# 408  7.246755
# 323  2.925704
# 22   2.428752
# 325  2.685530
#
# [125 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([3.22104962, 2.22649586, 3.20639751, 1.80094265, 1.75491697,
#        2.39788959, 4.44394856, 4.8553223 , 1.90073563, 3.50663725,
#        4.09739956, 2.43935948, 2.86129131, 3.54705457, 2.79365857,
#        1.81833588, 2.52828034, 5.16040515, 2.45833963, 3.99602294,
#        1.84537023, 2.73596463, 2.63784126, 1.24695543, 4.60759578,
#        1.73989567, 2.47142084, 5.37089273, 4.21730026, 4.12681139,
#        1.35827628, 3.72161451, 2.84090324, 3.71146161, 4.00039065,
#        4.00964079, 1.28472812, 2.48373534, 1.33171312, 2.25751657,
#        5.3486936 , 4.4198759 , 5.08337826, 4.83147863, 2.94614642,
#        2.16052564, 1.63795469, 3.17249028, 2.68347609, 1.47639698,
#        4.02858369, 2.99337407, 5.13418108, 3.71741093, 3.59011653,
#        3.34540269, 3.54989015, 3.94600222, 4.92545217, 3.82002018,
#        4.8932121 , 1.57160471, 5.09006277, 2.35288964, 2.22202521,
#        5.38251776, 4.71829266, 3.76996937, 2.41532445, 5.31932093,
#        4.52517364, 3.42982573, 3.04702149, 3.07684193, 1.95083037,
#        3.13282829, 5.10730205, 5.37310894, 2.69924581, 4.25076335,
#        4.2611225 , 1.6259267 , 2.71372984, 3.93784239, 3.18437055,
#        1.74351297, 3.6468798 , 4.26770864, 2.98916416, 2.05695185,
#        4.48350891, 3.56378597, 4.83640417, 5.15566399, 2.00619982,
#        4.46148299, 3.65907839, 1.59885448, 3.62232357, 4.66789531,
#        4.50846748, 5.42548818, 2.57954021, 4.56064   , 4.382052  ,
#        2.22920345, 4.94599067, 4.2699531 , 4.98640067, 4.99453018,
#        1.51635516, 2.6419841 , 4.73644893, 2.37100145, 4.28014614,
#        2.61295969, 1.53772219, 4.81185889, 5.47114179, 2.76738297,
#        3.71217748, 5.38644189, 2.27051185, 1.91215758, 2.09732135])

# %%
print("Intercept",model.intercept_)
print("Slope",model.coef_)
# Out:
# Intercept 0.16077353972243014
# Slope [0.72110461]

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
print("R-squared",r2_score(y_test,y_pred))
# Out:
# MAE 0.6391082095595165
# MSE 0.6126899439655095
# RMSE 0.7827451334665131
# R-squared 0.6892098434234475

# %%
y_train_pred = model.predict(X_train)
print("R-squared (Training)", r2_score(y_train, y_train_pred))
# Out:
# R-squared (Training) 0.7681252878666832

# %%
print("R-squared (Test)", r2_score(y_test, y_pred))
# Out:
# R-squared (Test) 0.6892098434234475

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y,color='green',label="actual data")
plt.plot(X_test,y_pred,color='red',label="regression line")
plt.legend()
plt.xlabel("Income")
plt.ylabel("Happiness")
plt.grid()
plt.show()

# %%
new_data=pd.DataFrame(
    {
        "income":[7.32]
    }
)

# %%
prediction=model.predict(new_data)
prediction
# Out:
# array([5.43925932])
